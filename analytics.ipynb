# %%
import matplotlib.pyplot as plt
import pandas as pd
import json

file = "racer_tv.json"
data = None
with open(file, 'r') as f:
    data = json.load(f)

channel_id, stats = data.popitem()
print(channel_id)
channel_stats = stats["channel_statistics"]
video_stats = stats["video_data"]
# Out:
# UC75V5b1wgQgf0cU_QN6Vw2g

# %%
#channel statistics
print('views', channel_stats["viewCount"])
print('subscriber', channel_stats["subscriberCount"])
print('videos', channel_stats["videoCount"])
# Out:
# views 95633595
# subscriber 437000
# videos 358

# %%
#video statistics
sorted_vids = sorted(video_stats.items(), key=lambda item: int(item[1]["viewCount"]), reverse=True)
stats = []
for vid in sorted_vids:
    video_id = vid[0]
    title = vid[1]["title"]
    views = int(vid[1]["viewCount"])
    likes = int(vid[1]["likeCount"])
    comments = int(vid[1]["commentCount"])
    stats.append([title,views,likes,comments])

# %%
#create pandas dataframe

df = pd.DataFrame(stats, columns=["title","views","likes","comments"])
df.head(10)
# Out:
#                                                title    views  likes  comments
# 0          Cafe Racer (2020 Top 10 Best Cafe Racers)  2209589  22779      1076
# 1         Cafe Racers (2021 Top 10 Best Motorcycles)  1265965  12457       418
# 2    Cafe Racer (Moto Guzzi La Macchina 850 By MCNC)   830142  10544       785
# 3  Small Cafe Racers 3 (125cc) - Honda CG, Honda ...   711045   9693       286
# 4  Cafe Racer (Honda Hornet by Retrorides by Lour...   676975   9388       402
# 5  Cafe Racer (Honda Super Cub 2 By Eak K Speed C...   490164   4947       236
# 6     Cafe Racer (SUZUKI GN250 by Solace Motorcycle)   450099   6368       350
# 7  Cafe Racer (Honda CB1100 by South Garage Motor...   435075   6283       329
# 8         Cafe Racer (Yamaha GTS 1000 by Aki Suokas)   354013   7437       431
# 9  Cafe Racer (Yamaha Virago XV750 by DEVELiGENCE...   335473   5310       212

# %%
top10 = df.head(10)
ax = top10.plot.bar(x="title", y="views", figsize=(12,8), fontsize=14)

# %%
bottom10 = df.tail(10)
ax = bottom10.plot.bar(x="title", y="views", figsize=(12,8), fontsize=14)

# %%
topl10 = df.head(10)
ax = topl10.plot.bar(x="title", y="likes", figsize=(12,8), fontsize=14)
